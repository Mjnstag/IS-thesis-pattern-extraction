# %%
import pandas as pd
from pathlib import Path
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt 

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
# from https://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
RUG = pd.read_pickle("../rug_timeseries.pkl")
RUG = RUG[::10]
dfs = [RUG.filter([i]) for i in RUG]

# %%
RUG

# %% [markdown]
# # Timeseries LSTM

# %%
def func(df, name):

    df2 = df.copy()

    scaler = MinMaxScaler(feature_range=(0, 1))
    dataset = scaler.fit_transform(df2)

    train_size = int(len(dataset) * 0.67)
    test_size = len(dataset) - train_size
    train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]


    # convert an array of values into a dataset matrix
    def create_dataset(dataset, look_back=3):
        dataX, dataY = [], []
        for i in range(len(dataset)-look_back-1):
            a = dataset[i:(i+look_back), 0]
            dataX.append(a)
            dataY.append(dataset[i + look_back, 0])
        return np.array(dataX), np.array(dataY)
    
    # reshape into X=t and Y=t+1
    look_back = 3
    trainX, trainY = create_dataset(train, look_back)
    testX, testY = create_dataset(test, look_back)
    
    # reshape input to be [samples, time steps, features]
    trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
    testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

    callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)


    # create and fit the LSTM network
    model = Sequential()
    model.add(LSTM(4, input_shape=(1, look_back)))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse'])
    model.fit(trainX, trainY, epochs=100, verbose=2, callbacks=[callback])

    # make predictions
    trainPredict = model.predict(trainX)
    testPredict = model.predict(testX)
    # invert predictions
    trainPredict = scaler.inverse_transform(trainPredict)
    trainY = scaler.inverse_transform([trainY])
    testPredict = scaler.inverse_transform(testPredict)
    testY = scaler.inverse_transform([testY])
    # calculate root mean squared error
    trainScore = np.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
    # print('Train Score: %.2f RMSE' % (trainScore))
    testScore = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
    # print('Test Score: %.2f RMSE' % (testScore))

    return (name, (trainScore, testScore))

# %%
results = []

for name, df in zip([i for i in RUG], dfs):
    print(name)
    
    if df.isnull().values.any():
        print("NaN")
        print("-------------")
        continue

    r = func(df, name)
    print("-------------")
    results.append(r)
# Out:
# Ede\Pompstation Edese bos\Straat 03\Flow
# Epoch 1/100
# 2201/2201 - 23s - loss: 0.0407 - mse: 0.0407 - 23s/epoch - 10ms/step
# Epoch 2/100
# 2201/2201 - 16s - loss: 0.0046 - mse: 0.0046 - 16s/epoch - 7ms/step
# Epoch 3/100
# 2201/2201 - 14s - loss: 0.0033 - mse: 0.0033 - 14s/epoch - 6ms/step
# Epoch 4/100
# 2201/2201 - 13s - loss: 0.0032 - mse: 0.0032 - 13s/epoch - 6ms/step
# Epoch 5/100
# 2201/2201 - 16s - loss: 0.0032 - mse: 0.0032 - 16s/epoch - 7ms/step
# Epoch 6/100
# 2201/2201 - 14s - loss: 0.0032 - mse: 0.0032 - 14s/epoch - 6ms/step
# Epoch 7/100
# 2201/2201 - 13s - loss: 0.0032 - mse: 0.0032 - 13s/epoch - 6ms/step
# Epoch 8/100
# 2201/2201 - 15s - loss: 0.0032 - mse: 0.0032 - 15s/epoch - 7ms/step
# Epoch 9/100
# 2201/2201 - 13s - loss: 0.0032 - mse: 0.0032 - 13s/epoch - 6ms/step
# Epoch 10/100
# 2201/2201 - 9s - loss: 0.0032 - mse: 0.0032 - 9s/epoch - 4ms/step
# Epoch 11/100
# 2201/2201 - 12s - loss: 0.0032 - mse: 0.0032 - 12s/epoch - 5ms/step
# Epoch 12/100
# 2201/2201 - 14s - loss: 0.0032 - mse: 0.0032 - 14s/epoch - 6ms/step
# Epoch 13/100
# 2201/2201 - 15s - loss: 0.0032 - mse: 0.0032 - 15s/epoch - 7ms/step
# Epoch 14/100
# 2201/2201 - 12s - loss: 0.0032 - mse: 0.0032 - 12s/epoch - 5ms/step
# Epoch 15/100
# 2201/2201 - 9s - loss: 0.0032 - mse: 0.0032 - 9s/epoch - 4ms/step
# Epoch 16/100
# 2201/2201 - 12s - loss: 0.0032 - mse: 0.0032 - 12s/epoch - 6ms/step
# Epoch 17/100
# 2201/2201 - 13s - loss: 0.0032 - mse: 0.0032 - 13s/epoch - 6ms/step
# Epoch 18/100
# 2201/2201 - 14s - loss: 0.0032 - mse: 0.0032 - 14s/epoch - 6ms/step
# Epoch 19/100
# 2201/2201 - 12s - loss: 0.0032 - mse: 0.0032 - 12s/epoch - 5ms/step
# Epoch 20/100
# 2201/2201 - 11s - loss: 0.0032 - mse: 0.0032 - 11s/epoch - 5ms/step
# Epoch 21/100
# 2201/2201 - 11s - loss: 0.0032 - mse: 0.0032 - 11s/epoch - 5ms/step
# Epoch 22/100
# 2201/2201 - 10s - loss: 0.0032 - mse: 0.0032 - 10s/epoch - 5ms/step
# Epoch 23/100
# 2201/2201 - 10s - loss: 0.0032 - mse: 0.0032 - 10s/epoch - 5ms/step
# Epoch 24/100
# 2201/2201 - 10s - loss: 0.0032 - mse: 0.0032 - 10s/epoch - 5ms/step
# Epoch 25/100
# 2201/2201 - 11s - loss: 0.0032 - mse: 0.0032 - 11s/epoch - 5ms/step
# 2201/2201 [==============================] - 5s 2ms/step
# 1084/1084 [==============================] - 2s 2ms/step
# -------------
# Oosterbeek-hoog\Fletcher BV|Supplied
# Epoch 1/100
# 2201/2201 - 13s - loss: 0.0025 - mse: 0.0025 - 13s/epoch - 6ms/step
# Epoch 2/100
# 2201/2201 - 15s - loss: 7.8873e-04 - mse: 7.8873e-04 - 15s/epoch - 7ms/step
# Epoch 3/100
# 2201/2201 - 14s - loss: 7.4684e-04 - mse: 7.4684e-04 - 14s/epoch - 7ms/step
# Epoch 4/100
# 2201/2201 - 15s - loss: 7.3954e-04 - mse: 7.3954e-04 - 15s/epoch - 7ms/step
# Epoch 5/100
# 2201/2201 - 15s - loss: 7.3553e-04 - mse: 7.3553e-04 - 15s/epoch - 7ms/step
# Epoch 6/100
# 2201/2201 - 14s - loss: 7.3206e-04 - mse: 7.3206e-04 - 14s/epoch - 7ms/step
# Epoch 7/100
# 2201/2201 - 9s - loss: 7.2977e-04 - mse: 7.2977e-04 - 9s/epoch - 4ms/step
# Epoch 8/100
# 2201/2201 - 9s - loss: 7.2817e-04 - mse: 7.2817e-04 - 9s/epoch - 4ms/step
# Epoch 9/100
# 2201/2201 - 9s - loss: 7.2744e-04 - mse: 7.2744e-04 - 9s/epoch - 4ms/step
# Epoch 10/100
# 2201/2201 - 9s - loss: 7.2770e-04 - mse: 7.2770e-04 - 9s/epoch - 4ms/step
# Epoch 11/100
# 2201/2201 - 9s - loss: 7.2443e-04 - mse: 7.2443e-04 - 9s/epoch - 4ms/step
# Epoch 12/100
# 2201/2201 - 9s - loss: 7.2598e-04 - mse: 7.2598e-04 - 9s/epoch - 4ms/step
# Epoch 13/100
# 2201/2201 - 9s - loss: 7.2353e-04 - mse: 7.2353e-04 - 9s/epoch - 4ms/step
# Epoch 14/100
# 2201/2201 - 9s - loss: 7.2349e-04 - mse: 7.2349e-04 - 9s/epoch - 4ms/step
# Epoch 15/100
# 2201/2201 - 9s - loss: 7.2139e-04 - mse: 7.2139e-04 - 9s/epoch - 4ms/step
# Epoch 16/100
# 2201/2201 - 9s - loss: 7.2059e-04 - mse: 7.2059e-04 - 9s/epoch - 4ms/step
# Epoch 17/100
# 2201/2201 - 9s - loss: 7.2066e-04 - mse: 7.2066e-04 - 9s/epoch - 4ms/step
# Epoch 18/100
# 2201/2201 - 9s - loss: 7.1969e-04 - mse: 7.1969e-04 - 9s/epoch - 4ms/step
# Epoch 19/100
# 2201/2201 - 9s - loss: 7.1932e-04 - mse: 7.1932e-04 - 9s/epoch - 4ms/step
# Epoch 20/100
# 2201/2201 - 9s - loss: 7.1978e-04 - mse: 7.1978e-04 - 9s/epoch - 4ms/step
# Epoch 21/100
# 2201/2201 - 9s - loss: 7.1760e-04 - mse: 7.1760e-04 - 9s/epoch - 4ms/step
# Epoch 22/100
# 2201/2201 - 9s - loss: 7.1642e-04 - mse: 7.1642e-04 - 9s/epoch - 4ms/step
# Epoch 23/100
# 2201/2201 - 9s - loss: 7.1585e-04 - mse: 7.1585e-04 - 9s/epoch - 4ms/step
# Epoch 24/100
# 2201/2201 - 9s - loss: 7.1663e-04 - mse: 7.1663e-04 - 9s/epoch - 4ms/step
# Epoch 25/100
# 2201/2201 - 9s - loss: 7.1537e-04 - mse: 7.1537e-04 - 9s/epoch - 4ms/step
# Epoch 26/100
# 2201/2201 - 9s - loss: 7.1622e-04 - mse: 7.1622e-04 - 9s/epoch - 4ms/step
# Epoch 27/100
# 2201/2201 - 9s - loss: 7.1412e-04 - mse: 7.1412e-04 - 9s/epoch - 4ms/step
# Epoch 28/100
# 2201/2201 - 9s - loss: 7.1450e-04 - mse: 7.1450e-04 - 9s/epoch - 4ms/step
# Epoch 29/100
# 2201/2201 - 9s - loss: 7.1382e-04 - mse: 7.1382e-04 - 9s/epoch - 4ms/step
# Epoch 30/100
# 2201/2201 - 9s - loss: 7.1313e-04 - mse: 7.1313e-04 - 9s/epoch - 4ms/step
# Epoch 31/100
# 2201/2201 - 9s - loss: 7.1354e-04 - mse: 7.1354e-04 - 9s/epoch - 4ms/step
# Epoch 32/100
# 2201/2201 - 9s - loss: 7.1308e-04 - mse: 7.1308e-04 - 9s/epoch - 4ms/step
# Epoch 33/100
# 2201/2201 - 9s - loss: 7.1340e-04 - mse: 7.1340e-04 - 9s/epoch - 4ms/step
# Epoch 34/100
# 2201/2201 - 9s - loss: 7.1272e-04 - mse: 7.1272e-04 - 9s/epoch - 4ms/step
# Epoch 35/100
# 2201/2201 - 9s - loss: 7.1348e-04 - mse: 7.1348e-04 - 9s/epoch - 4ms/step
# Epoch 36/100
# 2201/2201 - 9s - loss: 7.1348e-04 - mse: 7.1348e-04 - 9s/epoch - 4ms/step
# Epoch 37/100
# 2201/2201 - 9s - loss: 7.1271e-04 - mse: 7.1271e-04 - 9s/epoch - 4ms/step
# Epoch 38/100
# 2201/2201 - 9s - loss: 7.1414e-04 - mse: 7.1414e-04 - 9s/epoch - 4ms/step
# Epoch 39/100
# 2201/2201 - 9s - loss: 7.1302e-04 - mse: 7.1302e-04 - 9s/epoch - 4ms/step
# Epoch 40/100
# 2201/2201 - 9s - loss: 7.1399e-04 - mse: 7.1399e-04 - 9s/epoch - 4ms/step
# 2201/2201 [==============================] - 4s 2ms/step
# 1084/1084 [==============================] - 2s 2ms/step
# -------------
# Renkum-Heelsum\Renkum|Supplied
# NaN
# Renkum-Heelsum\Parenco BV|Supplied
# Epoch 1/100
# 2201/2201 - 10s - loss: 0.0017 - mse: 0.0017 - 10s/epoch - 5ms/step
# Epoch 2/100
# 2201/2201 - 9s - loss: 4.2371e-04 - mse: 4.2371e-04 - 9s/epoch - 4ms/step
# Epoch 3/100
# 2201/2201 - 9s - loss: 3.8877e-04 - mse: 3.8877e-04 - 9s/epoch - 4ms/step
# Epoch 4/100
# 2201/2201 - 9s - loss: 3.8208e-04 - mse: 3.8208e-04 - 9s/epoch - 4ms/step
# Epoch 5/100
# 2201/2201 - 9s - loss: 3.8147e-04 - mse: 3.8147e-04 - 9s/epoch - 4ms/step
# Epoch 6/100
# 2201/2201 - 9s - loss: 3.8117e-04 - mse: 3.8117e-04 - 9s/epoch - 4ms/step
# Epoch 7/100
# 2201/2201 - 9s - loss: 3.8057e-04 - mse: 3.8057e-04 - 9s/epoch - 4ms/step
# Epoch 8/100
# 2201/2201 - 9s - loss: 3.8023e-04 - mse: 3.8023e-04 - 9s/epoch - 4ms/step
# Epoch 9/100
# 2201/2201 - 9s - loss: 3.7842e-04 - mse: 3.7842e-04 - 9s/epoch - 4ms/step
# Epoch 10/100
# 2201/2201 - 9s - loss: 3.7906e-04 - mse: 3.7906e-04 - 9s/epoch - 4ms/step
# Epoch 11/100
# 2201/2201 - 9s - loss: 3.7823e-04 - mse: 3.7823e-04 - 9s/epoch - 4ms/step
# Epoch 12/100
# 2201/2201 - 9s - loss: 3.7846e-04 - mse: 3.7846e-04 - 9s/epoch - 4ms/step
# Epoch 13/100
# 2201/2201 - 9s - loss: 3.7776e-04 - mse: 3.7776e-04 - 9s/epoch - 4ms/step
# Epoch 14/100
# 2201/2201 - 9s - loss: 3.7799e-04 - mse: 3.7799e-04 - 9s/epoch - 4ms/step
# Epoch 15/100
# 2201/2201 - 9s - loss: 3.7755e-04 - mse: 3.7755e-04 - 9s/epoch - 4ms/step
# Epoch 16/100
# 2201/2201 - 9s - loss: 3.7707e-04 - mse: 3.7707e-04 - 9s/epoch - 4ms/step
# Epoch 17/100
# 2201/2201 - 9s - loss: 3.7766e-04 - mse: 3.7766e-04 - 9s/epoch - 4ms/step
# Epoch 18/100
# 2201/2201 - 9s - loss: 3.7910e-04 - mse: 3.7910e-04 - 9s/epoch - 4ms/step
# Epoch 19/100
# 2201/2201 - 9s - loss: 3.7781e-04 - mse: 3.7781e-04 - 9s/epoch - 4ms/step
# 2201/2201 [==============================] - 4s 2ms/step
# 1084/1084 [==============================] - 2s 2ms/step
# -------------
# Renkum-Heelsum\Zorggroep|Supplied
# Epoch 1/100
# 2201/2201 - 10s - loss: 9.5737e-04 - mse: 9.5737e-04 - 10s/epoch - 5ms/step
# Epoch 2/100
# 2201/2201 - 9s - loss: 4.6363e-04 - mse: 4.6363e-04 - 9s/epoch - 4ms/step
# Epoch 3/100
# 2201/2201 - 9s - loss: 4.4785e-04 - mse: 4.4785e-04 - 9s/epoch - 4ms/step
# Epoch 4/100
# 2201/2201 - 9s - loss: 4.4448e-04 - mse: 4.4448e-04 - 9s/epoch - 4ms/step
# Epoch 5/100
# 2201/2201 - 9s - loss: 4.4262e-04 - mse: 4.4262e-04 - 9s/epoch - 4ms/step
# Epoch 6/100
# 2201/2201 - 9s - loss: 4.4349e-04 - mse: 4.4349e-04 - 9s/epoch - 4ms/step
# Epoch 7/100
# 2201/2201 - 9s - loss: 4.4309e-04 - mse: 4.4309e-04 - 9s/epoch - 4ms/step
# Epoch 8/100
# 2201/2201 - 9s - loss: 4.4288e-04 - mse: 4.4288e-04 - 9s/epoch - 4ms/step
# 2201/2201 [==============================] - 4s 2ms/step
# 1084/1084 [==============================] - 2s 2ms/step
# -------------
# Pompstation Oosterbeek\Straat 01\Head
# Epoch 1/100
# 2201/2201 - 10s - loss: 0.0158 - mse: 0.0158 - 10s/epoch - 5ms/step
# Epoch 2/100
# 2201/2201 - 9s - loss: 4.4110e-05 - mse: 4.4110e-05 - 9s/epoch - 4ms/step
# Epoch 3/100
# 2201/2201 - 9s - loss: 4.3859e-05 - mse: 4.3859e-05 - 9s/epoch - 4ms/step
# Epoch 4/100
# 2201/2201 - 9s - loss: 4.3073e-05 - mse: 4.3073e-05 - 9s/epoch - 4ms/step
# Epoch 5/100
# 2201/2201 - 9s - loss: 4.1934e-05 - mse: 4.1934e-05 - 9s/epoch - 4ms/step
# Epoch 6/100
# 2201/2201 - 9s - loss: 3.9686e-05 - mse: 3.9686e-05 - 9s/epoch - 4ms/step
# Epoch 7/100
# 2201/2201 - 9s - loss: 3.7835e-05 - mse: 3.7835e-05 - 9s/epoch - 4ms/step
# Epoch 8/100
# 2201/2201 - 9s - loss: 3.6913e-05 - mse: 3.6913e-05 - 9s/epoch - 4ms/step
# Epoch 9/100
# 2201/2201 - 9s - loss: 3.5580e-05 - mse: 3.5580e-05 - 9s/epoch - 4ms/step
# Epoch 10/100
# 2201/2201 - 9s - loss: 3.5141e-05 - mse: 3.5141e-05 - 9s/epoch - 4ms/step
# Epoch 11/100
# 2201/2201 - 9s - loss: 3.4452e-05 - mse: 3.4452e-05 - 9s/epoch - 4ms/step
# Epoch 12/100
# 2201/2201 - 9s - loss: 3.4039e-05 - mse: 3.4039e-05 - 9s/epoch - 4ms/step
# Epoch 13/100
# 2201/2201 - 9s - loss: 3.3121e-05 - mse: 3.3121e-05 - 9s/epoch - 4ms/step
# Epoch 14/100
# 2201/2201 - 9s - loss: 3.2687e-05 - mse: 3.2687e-05 - 9s/epoch - 4ms/step
# Epoch 15/100
# 2201/2201 - 9s - loss: 3.2261e-05 - mse: 3.2261e-05 - 9s/epoch - 4ms/step
# Epoch 16/100
# 2201/2201 - 9s - loss: 3.1470e-05 - mse: 3.1470e-05 - 9s/epoch - 4ms/step
# Epoch 17/100
# 2201/2201 - 9s - loss: 3.1368e-05 - mse: 3.1368e-05 - 9s/epoch - 4ms/step
# Epoch 18/100
# 2201/2201 - 9s - loss: 3.0899e-05 - mse: 3.0899e-05 - 9s/epoch - 4ms/step
# Epoch 19/100
# 2201/2201 - 9s - loss: 3.0663e-05 - mse: 3.0663e-05 - 9s/epoch - 4ms/step
# Epoch 20/100
# 2201/2201 - 9s - loss: 3.0292e-05 - mse: 3.0292e-05 - 9s/epoch - 4ms/step
# Epoch 21/100
# 2201/2201 - 9s - loss: 2.9661e-05 - mse: 2.9661e-05 - 9s/epoch - 4ms/step
# Epoch 22/100
# 2201/2201 - 9s - loss: 2.9529e-05 - mse: 2.9529e-05 - 9s/epoch - 4ms/step
# Epoch 23/100
# 2201/2201 - 9s - loss: 2.8932e-05 - mse: 2.8932e-05 - 9s/epoch - 4ms/step
# Epoch 24/100
# 2201/2201 - 9s - loss: 2.8887e-05 - mse: 2.8887e-05 - 9s/epoch - 4ms/step
# Epoch 25/100
# 2201/2201 - 9s - loss: 2.8446e-05 - mse: 2.8446e-05 - 9s/epoch - 4ms/step
# Epoch 26/100
# 2201/2201 - 9s - loss: 2.8421e-05 - mse: 2.8421e-05 - 9s/epoch - 4ms/step
# Epoch 27/100
# 2201/2201 - 9s - loss: 2.7791e-05 - mse: 2.7791e-05 - 9s/epoch - 4ms/step
# Epoch 28/100
# 2201/2201 - 9s - loss: 2.7653e-05 - mse: 2.7653e-05 - 9s/epoch - 4ms/step
# Epoch 29/100
# 2201/2201 - 9s - loss: 2.7427e-05 - mse: 2.7427e-05 - 9s/epoch - 4ms/step
# Epoch 30/100
# 2201/2201 - 9s - loss: 2.6751e-05 - mse: 2.6751e-05 - 9s/epoch - 4ms/step
# Epoch 31/100
# 2201/2201 - 9s - loss: 2.6861e-05 - mse: 2.6861e-05 - 9s/epoch - 4ms/step
# Epoch 32/100
# 2201/2201 - 9s - loss: 2.6321e-05 - mse: 2.6321e-05 - 9s/epoch - 4ms/step
# Epoch 33/100
# 2201/2201 - 9s - loss: 2.6671e-05 - mse: 2.6671e-05 - 9s/epoch - 4ms/step
# Epoch 34/100
# 2201/2201 - 9s - loss: 2.5733e-05 - mse: 2.5733e-05 - 9s/epoch - 4ms/step
# Epoch 35/100
# 2201/2201 - 9s - loss: 2.5810e-05 - mse: 2.5810e-05 - 9s/epoch - 4ms/step
# Epoch 36/100
# 2201/2201 - 9s - loss: 2.5261e-05 - mse: 2.5261e-05 - 9s/epoch - 4ms/step
# Epoch 37/100
# 2201/2201 - 9s - loss: 2.5486e-05 - mse: 2.5486e-05 - 9s/epoch - 4ms/step
# Epoch 38/100
# 2201/2201 - 9s - loss: 2.4897e-05 - mse: 2.4897e-05 - 9s/epoch - 4ms/step
# Epoch 39/100
# 2201/2201 - 9s - loss: 2.4912e-05 - mse: 2.4912e-05 - 9s/epoch - 4ms/step
# Epoch 40/100
# 2201/2201 - 9s - loss: 2.4491e-05 - mse: 2.4491e-05 - 9s/epoch - 4ms/step
# Epoch 41/100
# 2201/2201 - 9s - loss: 2.4528e-05 - mse: 2.4528e-05 - 9s/epoch - 4ms/step
# Epoch 42/100
# 2201/2201 - 9s - loss: 2.4063e-05 - mse: 2.4063e-05 - 9s/epoch - 4ms/step
# Epoch 43/100
# 2201/2201 - 9s - loss: 2.4181e-05 - mse: 2.4181e-05 - 9s/epoch - 4ms/step
# Epoch 44/100
# 2201/2201 - 9s - loss: 2.3738e-05 - mse: 2.3738e-05 - 9s/epoch - 4ms/step
# Epoch 45/100
# 2201/2201 - 9s - loss: 2.3449e-05 - mse: 2.3449e-05 - 9s/epoch - 4ms/step
# Epoch 46/100
# 2201/2201 - 9s - loss: 2.3565e-05 - mse: 2.3565e-05 - 9s/epoch - 4ms/step
# Epoch 47/100
# 2201/2201 - 9s - loss: 2.3449e-05 - mse: 2.3449e-05 - 9s/epoch - 4ms/step
# Epoch 48/100
# 2201/2201 - 9s - loss: 2.2960e-05 - mse: 2.2960e-05 - 9s/epoch - 4ms/step
# Epoch 49/100
# 2201/2201 - 9s - loss: 2.2743e-05 - mse: 2.2743e-05 - 9s/epoch - 4ms/step
# Epoch 50/100
# 2201/2201 - 9s - loss: 2.2957e-05 - mse: 2.2957e-05 - 9s/epoch - 4ms/step
# Epoch 51/100
# 2201/2201 - 9s - loss: 2.2744e-05 - mse: 2.2744e-05 - 9s/epoch - 4ms/step
# Epoch 52/100
# 2201/2201 - 9s - loss: 2.2416e-05 - mse: 2.2416e-05 - 9s/epoch - 4ms/step
# Epoch 53/100
# 2201/2201 - 9s - loss: 2.2604e-05 - mse: 2.2604e-05 - 9s/epoch - 4ms/step
# Epoch 54/100
# 2201/2201 - 9s - loss: 2.2195e-05 - mse: 2.2195e-05 - 9s/epoch - 4ms/step
# Epoch 55/100
# 2201/2201 - 9s - loss: 2.2073e-05 - mse: 2.2073e-05 - 9s/epoch - 4ms/step
# Epoch 56/100
# 2201/2201 - 9s - loss: 2.1790e-05 - mse: 2.1790e-05 - 9s/epoch - 4ms/step
# Epoch 57/100
# 2201/2201 - 9s - loss: 2.2299e-05 - mse: 2.2299e-05 - 9s/epoch - 4ms/step
# Epoch 58/100
# 2201/2201 - 9s - loss: 2.1461e-05 - mse: 2.1461e-05 - 9s/epoch - 4ms/step
# Epoch 59/100
# 2201/2201 - 9s - loss: 2.1812e-05 - mse: 2.1812e-05 - 9s/epoch - 4ms/step
# Epoch 60/100
# 2201/2201 - 9s - loss: 2.1657e-05 - mse: 2.1657e-05 - 9s/epoch - 4ms/step
# Epoch 61/100
# 2201/2201 - 9s - loss: 2.1428e-05 - mse: 2.1428e-05 - 9s/epoch - 4ms/step
# Epoch 62/100
# 2201/2201 - 9s - loss: 2.1593e-05 - mse: 2.1593e-05 - 9s/epoch - 4ms/step
# Epoch 63/100
# 2201/2201 - 9s - loss: 2.1571e-05 - mse: 2.1571e-05 - 9s/epoch - 4ms/step
# Epoch 64/100
# 2201/2201 - 9s - loss: 2.1210e-05 - mse: 2.1210e-05 - 9s/epoch - 4ms/step
# Epoch 65/100
# 2201/2201 - 9s - loss: 2.1154e-05 - mse: 2.1154e-05 - 9s/epoch - 4ms/step
# Epoch 66/100
# 2201/2201 - 9s - loss: 2.1180e-05 - mse: 2.1180e-05 - 9s/epoch - 4ms/step
# Epoch 67/100
# 2201/2201 - 9s - loss: 2.1356e-05 - mse: 2.1356e-05 - 9s/epoch - 4ms/step
# Epoch 68/100
# 2201/2201 - 9s - loss: 2.0980e-05 - mse: 2.0980e-05 - 9s/epoch - 4ms/step
# Epoch 69/100
# 2201/2201 - 9s - loss: 2.0912e-05 - mse: 2.0912e-05 - 9s/epoch - 4ms/step
# Epoch 70/100
# 2201/2201 - 9s - loss: 2.1005e-05 - mse: 2.1005e-05 - 9s/epoch - 4ms/step
# Epoch 71/100
# 2201/2201 - 9s - loss: 2.1089e-05 - mse: 2.1089e-05 - 9s/epoch - 4ms/step
# Epoch 72/100
# 2201/2201 - 9s - loss: 2.0626e-05 - mse: 2.0626e-05 - 9s/epoch - 4ms/step
# Epoch 73/100
# 2201/2201 - 9s - loss: 2.0966e-05 - mse: 2.0966e-05 - 9s/epoch - 4ms/step
# Epoch 74/100
# 2201/2201 - 9s - loss: 2.0519e-05 - mse: 2.0519e-05 - 9s/epoch - 4ms/step
# Epoch 75/100
# 2201/2201 - 9s - loss: 2.0686e-05 - mse: 2.0686e-05 - 9s/epoch - 4ms/step
# Epoch 76/100
# 2201/2201 - 9s - loss: 2.0446e-05 - mse: 2.0446e-05 - 9s/epoch - 4ms/step
# Epoch 77/100
# 2201/2201 - 9s - loss: 2.0742e-05 - mse: 2.0742e-05 - 9s/epoch - 4ms/step
# Epoch 78/100
# 2201/2201 - 9s - loss: 2.0558e-05 - mse: 2.0558e-05 - 9s/epoch - 4ms/step
# Epoch 79/100
# 2201/2201 - 9s - loss: 2.0348e-05 - mse: 2.0348e-05 - 9s/epoch - 4ms/step
# Epoch 80/100
# 2201/2201 - 9s - loss: 2.0451e-05 - mse: 2.0451e-05 - 9s/epoch - 4ms/step
# Epoch 81/100
# 2201/2201 - 9s - loss: 2.0698e-05 - mse: 2.0698e-05 - 9s/epoch - 4ms/step
# Epoch 82/100
# 2201/2201 - 9s - loss: 1.9992e-05 - mse: 1.9992e-05 - 9s/epoch - 4ms/step
# Epoch 83/100
# 2201/2201 - 9s - loss: 2.0454e-05 - mse: 2.0454e-05 - 9s/epoch - 4ms/step
# Epoch 84/100
# 2201/2201 - 9s - loss: 2.0823e-05 - mse: 2.0823e-05 - 9s/epoch - 4ms/step
# Epoch 85/100
# 2201/2201 - 9s - loss: 2.0265e-05 - mse: 2.0265e-05 - 9s/epoch - 4ms/step
# 2201/2201 [==============================] - 4s 2ms/step
# 1084/1084 [==============================] - 2s 2ms/step
# -------------
# Pompstation Oosterbeek\Straat 02\Head
# Epoch 1/100
# 2201/2201 - 10s - loss: 0.0236 - mse: 0.0236 - 10s/epoch - 5ms/step
# Epoch 2/100
# 2201/2201 - 9s - loss: 4.9074e-05 - mse: 4.9074e-05 - 9s/epoch - 4ms/step
# Epoch 3/100
# 2201/2201 - 9s - loss: 4.8501e-05 - mse: 4.8501e-05 - 9s/epoch - 4ms/step
# Epoch 4/100
# 2201/2201 - 9s - loss: 4.6738e-05 - mse: 4.6738e-05 - 9s/epoch - 4ms/step
# Epoch 5/100
# 2201/2201 - 9s - loss: 4.3604e-05 - mse: 4.3604e-05 - 9s/epoch - 4ms/step
# Epoch 6/100
# 2201/2201 - 9s - loss: 3.9201e-05 - mse: 3.9201e-05 - 9s/epoch - 4ms/step
# Epoch 7/100
# 2201/2201 - 9s - loss: 3.7186e-05 - mse: 3.7186e-05 - 9s/epoch - 4ms/step
# Epoch 8/100
# 2201/2201 - 9s - loss: 3.5758e-05 - mse: 3.5758e-05 - 9s/epoch - 4ms/step
# Epoch 9/100
# 2201/2201 - 9s - loss: 3.4624e-05 - mse: 3.4624e-05 - 9s/epoch - 4ms/step
# Epoch 10/100
# 2201/2201 - 9s - loss: 3.4210e-05 - mse: 3.4210e-05 - 9s/epoch - 4ms/step
# Epoch 11/100
# 2201/2201 - 9s - loss: 3.3968e-05 - mse: 3.3968e-05 - 9s/epoch - 4ms/step
# Epoch 12/100
# 2201/2201 - 9s - loss: 3.3718e-05 - mse: 3.3718e-05 - 9s/epoch - 4ms/step
# Epoch 13/100
# 2201/2201 - 9s - loss: 3.3530e-05 - mse: 3.3530e-05 - 9s/epoch - 4ms/step
# Epoch 14/100
# 2201/2201 - 9s - loss: 3.3030e-05 - mse: 3.3030e-05 - 9s/epoch - 4ms/step
# Epoch 15/100
# 2201/2201 - 9s - loss: 3.2963e-05 - mse: 3.2963e-05 - 9s/epoch - 4ms/step
# Epoch 16/100
# 2201/2201 - 9s - loss: 3.3280e-05 - mse: 3.3280e-05 - 9s/epoch - 4ms/step
# Epoch 17/100
# 2201/2201 - 9s - loss: 3.2505e-05 - mse: 3.2505e-05 - 9s/epoch - 4ms/step
# Epoch 18/100
# 2201/2201 - 9s - loss: 3.2722e-05 - mse: 3.2722e-05 - 9s/epoch - 4ms/step
# Epoch 19/100
# 2201/2201 - 9s - loss: 3.2456e-05 - mse: 3.2456e-05 - 9s/epoch - 4ms/step
# Epoch 20/100
# 2201/2201 - 9s - loss: 3.2178e-05 - mse: 3.2178e-05 - 9s/epoch - 4ms/step
# Epoch 21/100
# 2201/2201 - 9s - loss: 3.2395e-05 - mse: 3.2395e-05 - 9s/epoch - 4ms/step
# Epoch 22/100
# 2201/2201 - 9s - loss: 3.2148e-05 - mse: 3.2148e-05 - 9s/epoch - 4ms/step
# Epoch 23/100
# 2201/2201 - 9s - loss: 3.2082e-05 - mse: 3.2082e-05 - 9s/epoch - 4ms/step
# Epoch 24/100
# 2201/2201 - 9s - loss: 3.1900e-05 - mse: 3.1900e-05 - 9s/epoch - 4ms/step
# Epoch 25/100
# 2201/2201 - 9s - loss: 3.1650e-05 - mse: 3.1650e-05 - 9s/epoch - 4ms/step
# Epoch 26/100
# 2201/2201 - 9s - loss: 3.1810e-05 - mse: 3.1810e-05 - 9s/epoch - 4ms/step
# Epoch 27/100
# 2201/2201 - 9s - loss: 3.1838e-05 - mse: 3.1838e-05 - 9s/epoch - 4ms/step
# Epoch 28/100
# 2201/2201 - 9s - loss: 3.1515e-05 - mse: 3.1515e-05 - 9s/epoch - 4ms/step
# Epoch 29/100
# 2201/2201 - 9s - loss: 3.1322e-05 - mse: 3.1322e-05 - 9s/epoch - 4ms/step
# Epoch 30/100
# 2201/2201 - 9s - loss: 3.1351e-05 - mse: 3.1351e-05 - 9s/epoch - 4ms/step
# Epoch 31/100
# 2201/2201 - 10s - loss: 3.1505e-05 - mse: 3.1505e-05 - 10s/epoch - 4ms/step
# Epoch 32/100
# 2201/2201 - 9s - loss: 3.1110e-05 - mse: 3.1110e-05 - 9s/epoch - 4ms/step
# Epoch 33/100
# 2201/2201 - 14s - loss: 3.1158e-05 - mse: 3.1158e-05 - 14s/epoch - 7ms/step
# Epoch 34/100
# 2201/2201 - 14s - loss: 3.1084e-05 - mse: 3.1084e-05 - 14s/epoch - 6ms/step
# Epoch 35/100
# 2201/2201 - 13s - loss: 3.0970e-05 - mse: 3.0970e-05 - 13s/epoch - 6ms/step
# Epoch 36/100
# 2201/2201 - 14s - loss: 3.0893e-05 - mse: 3.0893e-05 - 14s/epoch - 6ms/step
# Epoch 37/100
# 2201/2201 - 15s - loss: 3.1078e-05 - mse: 3.1078e-05 - 15s/epoch - 7ms/step
# Epoch 38/100
# 2201/2201 - 13s - loss: 3.0843e-05 - mse: 3.0843e-05 - 13s/epoch - 6ms/step
# Epoch 39/100
# 2201/2201 - 13s - loss: 3.0610e-05 - mse: 3.0610e-05 - 13s/epoch - 6ms/step
# Epoch 40/100
# 2201/2201 - 13s - loss: 3.0756e-05 - mse: 3.0756e-05 - 13s/epoch - 6ms/step
# Epoch 41/100
# 2201/2201 - 13s - loss: 3.0319e-05 - mse: 3.0319e-05 - 13s/epoch - 6ms/step
# Epoch 42/100
# 2201/2201 - 14s - loss: 3.0931e-05 - mse: 3.0931e-05 - 14s/epoch - 6ms/step
# Epoch 43/100
# 2201/2201 - 14s - loss: 3.0491e-05 - mse: 3.0491e-05 - 14s/epoch - 6ms/step
# Epoch 44/100
# 2201/2201 - 13s - loss: 3.0432e-05 - mse: 3.0432e-05 - 13s/epoch - 6ms/step
# 2201/2201 [==============================] - 8s 3ms/step
# 1084/1084 [==============================] - 4s 3ms/step
# -------------
# Reservoir Doorwerth\Straat 01\Flow
# Epoch 1/100
# 2201/2201 - 17s - loss: 0.0228 - mse: 0.0228 - 17s/epoch - 8ms/step
# Epoch 2/100
# 2201/2201 - 14s - loss: 4.0895e-05 - mse: 4.0895e-05 - 14s/epoch - 6ms/step
# Epoch 3/100
# 2201/2201 - 13s - loss: 4.0364e-05 - mse: 4.0364e-05 - 13s/epoch - 6ms/step
# Epoch 4/100
# 2201/2201 - 13s - loss: 3.9084e-05 - mse: 3.9084e-05 - 13s/epoch - 6ms/step
# Epoch 5/100
# 2201/2201 - 13s - loss: 3.6437e-05 - mse: 3.6437e-05 - 13s/epoch - 6ms/step
# Epoch 6/100
# 2201/2201 - 13s - loss: 3.3340e-05 - mse: 3.3340e-05 - 13s/epoch - 6ms/step
# Epoch 7/100
# 2201/2201 - 14s - loss: 3.1132e-05 - mse: 3.1132e-05 - 14s/epoch - 6ms/step
# Epoch 8/100
# 2201/2201 - 14s - loss: 2.9614e-05 - mse: 2.9614e-05 - 14s/epoch - 6ms/step
# Epoch 9/100
# 2201/2201 - 13s - loss: 2.8563e-05 - mse: 2.8563e-05 - 13s/epoch - 6ms/step
# Epoch 10/100
# 2201/2201 - 13s - loss: 2.8080e-05 - mse: 2.8080e-05 - 13s/epoch - 6ms/step
# Epoch 11/100
# 2201/2201 - 15s - loss: 2.7491e-05 - mse: 2.7491e-05 - 15s/epoch - 7ms/step
# Epoch 12/100
# 2201/2201 - 13s - loss: 2.7433e-05 - mse: 2.7433e-05 - 13s/epoch - 6ms/step
# Epoch 13/100
# 2201/2201 - 13s - loss: 2.7194e-05 - mse: 2.7194e-05 - 13s/epoch - 6ms/step
# Epoch 14/100
# 2201/2201 - 13s - loss: 2.6814e-05 - mse: 2.6814e-05 - 13s/epoch - 6ms/step
# Epoch 15/100
# 2201/2201 - 13s - loss: 2.6823e-05 - mse: 2.6823e-05 - 13s/epoch - 6ms/step
# Epoch 16/100
# 2201/2201 - 13s - loss: 2.6667e-05 - mse: 2.6667e-05 - 13s/epoch - 6ms/step
# Epoch 17/100
# 2201/2201 - 15s - loss: 2.6406e-05 - mse: 2.6406e-05 - 15s/epoch - 7ms/step
# Epoch 18/100
# 2201/2201 - 13s - loss: 2.6319e-05 - mse: 2.6319e-05 - 13s/epoch - 6ms/step
# Epoch 19/100
# 2201/2201 - 13s - loss: 2.6391e-05 - mse: 2.6391e-05 - 13s/epoch - 6ms/step
# Epoch 20/100
# 2201/2201 - 14s - loss: 2.6439e-05 - mse: 2.6439e-05 - 14s/epoch - 6ms/step
# Epoch 21/100
# 2201/2201 - 15s - loss: 2.6068e-05 - mse: 2.6068e-05 - 15s/epoch - 7ms/step
# Epoch 22/100
# 2201/2201 - 13s - loss: 2.6034e-05 - mse: 2.6034e-05 - 13s/epoch - 6ms/step
# Epoch 23/100
# 2201/2201 - 13s - loss: 2.5925e-05 - mse: 2.5925e-05 - 13s/epoch - 6ms/step
# Epoch 24/100
# 2201/2201 - 13s - loss: 2.5980e-05 - mse: 2.5980e-05 - 13s/epoch - 6ms/step
# Epoch 25/100
# 2201/2201 - 13s - loss: 2.5626e-05 - mse: 2.5626e-05 - 13s/epoch - 6ms/step
# Epoch 26/100
# 2201/2201 - 15s - loss: 2.5795e-05 - mse: 2.5795e-05 - 15s/epoch - 7ms/step
# Epoch 27/100
# 2201/2201 - 14s - loss: 2.5784e-05 - mse: 2.5784e-05 - 14s/epoch - 6ms/step
# Epoch 28/100
# 2201/2201 - 13s - loss: 2.5576e-05 - mse: 2.5576e-05 - 13s/epoch - 6ms/step
# Epoch 29/100
# 2201/2201 - 14s - loss: 2.5608e-05 - mse: 2.5608e-05 - 14s/epoch - 6ms/step
# Epoch 30/100
# 2201/2201 - 15s - loss: 2.5373e-05 - mse: 2.5373e-05 - 15s/epoch - 7ms/step
# Epoch 31/100
# 2201/2201 - 14s - loss: 2.5524e-05 - mse: 2.5524e-05 - 14s/epoch - 6ms/step
# Epoch 32/100
# 2201/2201 - 12s - loss: 2.5439e-05 - mse: 2.5439e-05 - 12s/epoch - 5ms/step
# Epoch 33/100
# 2201/2201 - 10s - loss: 2.5419e-05 - mse: 2.5419e-05 - 10s/epoch - 5ms/step
# 2201/2201 [==============================] - 5s 2ms/step
# 1084/1084 [==============================] - 2s 2ms/step
# -------------
# Reservoir Doorwerth\Straat 02\Head
# Epoch 1/100
# 2201/2201 - 11s - loss: 0.0139 - mse: 0.0139 - 11s/epoch - 5ms/step
# Epoch 2/100
# 2201/2201 - 10s - loss: 6.4951e-04 - mse: 6.4951e-04 - 10s/epoch - 5ms/step
# Epoch 3/100
# 2201/2201 - 10s - loss: 5.5233e-04 - mse: 5.5233e-04 - 10s/epoch - 5ms/step
# Epoch 4/100
# 2201/2201 - 10s - loss: 4.6003e-04 - mse: 4.6003e-04 - 10s/epoch - 5ms/step
# Epoch 5/100
# 2201/2201 - 10s - loss: 3.8985e-04 - mse: 3.8985e-04 - 10s/epoch - 5ms/step
# Epoch 6/100
# 2201/2201 - 10s - loss: 3.4815e-04 - mse: 3.4815e-04 - 10s/epoch - 5ms/step
# Epoch 7/100
# 2201/2201 - 10s - loss: 3.2548e-04 - mse: 3.2548e-04 - 10s/epoch - 5ms/step
# Epoch 8/100
# 2201/2201 - 10s - loss: 3.1590e-04 - mse: 3.1590e-04 - 10s/epoch - 5ms/step
# Epoch 9/100
# 2201/2201 - 10s - loss: 3.1049e-04 - mse: 3.1049e-04 - 10s/epoch - 5ms/step
# Epoch 10/100
# 2201/2201 - 10s - loss: 3.0777e-04 - mse: 3.0777e-04 - 10s/epoch - 5ms/step
# Epoch 11/100
# 2201/2201 - 10s - loss: 3.0544e-04 - mse: 3.0544e-04 - 10s/epoch - 5ms/step
# Epoch 12/100
# 2201/2201 - 10s - loss: 3.0519e-04 - mse: 3.0519e-04 - 10s/epoch - 5ms/step
# Epoch 13/100
# 2201/2201 - 10s - loss: 3.0320e-04 - mse: 3.0320e-04 - 10s/epoch - 5ms/step
# Epoch 14/100
# 2201/2201 - 10s - loss: 3.0264e-04 - mse: 3.0264e-04 - 10s/epoch - 5ms/step
# Epoch 15/100
# 2201/2201 - 10s - loss: 3.0329e-04 - mse: 3.0329e-04 - 10s/epoch - 5ms/step
# Epoch 16/100
# 2201/2201 - 10s - loss: 3.0167e-04 - mse: 3.0167e-04 - 10s/epoch - 5ms/step
# Epoch 17/100
# 2201/2201 - 10s - loss: 3.0247e-04 - mse: 3.0247e-04 - 10s/epoch - 5ms/step
# Epoch 18/100
# 2201/2201 - 10s - loss: 3.0188e-04 - mse: 3.0188e-04 - 10s/epoch - 5ms/step
# Epoch 19/100
# 2201/2201 - 10s - loss: 3.0141e-04 - mse: 3.0141e-04 - 10s/epoch - 5ms/step
# Epoch 20/100
# 2201/2201 - 10s - loss: 3.0197e-04 - mse: 3.0197e-04 - 10s/epoch - 5ms/step
# Epoch 21/100
# 2201/2201 - 10s - loss: 3.0080e-04 - mse: 3.0080e-04 - 10s/epoch - 5ms/step
# Epoch 22/100
# 2201/2201 - 10s - loss: 3.0130e-04 - mse: 3.0130e-04 - 10s/epoch - 5ms/step
# Epoch 23/100
# 2201/2201 - 10s - loss: 3.0091e-04 - mse: 3.0091e-04 - 10s/epoch - 5ms/step
# Epoch 24/100
# 2201/2201 - 10s - loss: 3.0189e-04 - mse: 3.0189e-04 - 10s/epoch - 5ms/step
# 2201/2201 [==============================] - 5s 2ms/step
# 1084/1084 [==============================] - 2s 2ms/step
# -------------
# Reservoir Doorwerth\Straat 03\Flow
# Epoch 1/100
# 2201/2201 - 11s - loss: 0.0089 - mse: 0.0089 - 11s/epoch - 5ms/step
# Epoch 2/100
# 2201/2201 - 10s - loss: 0.0039 - mse: 0.0039 - 10s/epoch - 5ms/step
# Epoch 3/100
# 2201/2201 - 10s - loss: 0.0038 - mse: 0.0038 - 10s/epoch - 5ms/step
# Epoch 4/100
# 2201/2201 - 10s - loss: 0.0037 - mse: 0.0037 - 10s/epoch - 5ms/step
# Epoch 5/100
# 2201/2201 - 10s - loss: 0.0037 - mse: 0.0037 - 10s/epoch - 5ms/step
# Epoch 6/100
# 2201/2201 - 10s - loss: 0.0037 - mse: 0.0037 - 10s/epoch - 5ms/step
# Epoch 7/100
# 2201/2201 - 10s - loss: 0.0037 - mse: 0.0037 - 10s/epoch - 5ms/step
# Epoch 8/100
# 2201/2201 - 10s - loss: 0.0037 - mse: 0.0037 - 10s/epoch - 5ms/step
# Epoch 9/100
# 2201/2201 - 10s - loss: 0.0037 - mse: 0.0037 - 10s/epoch - 5ms/step
# Epoch 10/100
# 2201/2201 - 10s - loss: 0.0037 - mse: 0.0037 - 10s/epoch - 5ms/step
# Epoch 11/100
# 2201/2201 - 10s - loss: 0.0037 - mse: 0.0037 - 10s/epoch - 5ms/step
# Epoch 12/100
# 2201/2201 - 10s - loss: 0.0037 - mse: 0.0037 - 10s/epoch - 5ms/step
# 2201/2201 [==============================] - 5s 2ms/step
# 1084/1084 [==============================] - 3s 2ms/step
# -------------
# Pompstation Wageningseberg\Head
# Epoch 1/100
# 2201/2201 - 12s - loss: 0.0607 - mse: 0.0607 - 12s/epoch - 5ms/step
# Epoch 2/100
# 2201/2201 - 10s - loss: 3.0605e-04 - mse: 3.0605e-04 - 10s/epoch - 5ms/step
# Epoch 3/100
# 2201/2201 - 10s - loss: 2.5694e-04 - mse: 2.5694e-04 - 10s/epoch - 5ms/step
# Epoch 4/100
# 2201/2201 - 10s - loss: 1.4714e-04 - mse: 1.4714e-04 - 10s/epoch - 5ms/step
# Epoch 5/100
# 2201/2201 - 10s - loss: 8.5410e-05 - mse: 8.5410e-05 - 10s/epoch - 5ms/step
# Epoch 6/100
# 2201/2201 - 10s - loss: 7.3636e-05 - mse: 7.3636e-05 - 10s/epoch - 5ms/step
# Epoch 7/100
# 2201/2201 - 10s - loss: 7.0706e-05 - mse: 7.0706e-05 - 10s/epoch - 5ms/step
# Epoch 8/100
# 2201/2201 - 10s - loss: 6.8968e-05 - mse: 6.8968e-05 - 10s/epoch - 5ms/step
# Epoch 9/100
# 2201/2201 - 10s - loss: 6.7217e-05 - mse: 6.7217e-05 - 10s/epoch - 5ms/step
# Epoch 10/100
# 2201/2201 - 10s - loss: 6.6426e-05 - mse: 6.6426e-05 - 10s/epoch - 5ms/step
# Epoch 11/100
# 2201/2201 - 10s - loss: 6.4953e-05 - mse: 6.4953e-05 - 10s/epoch - 5ms/step
# Epoch 12/100
# 2201/2201 - 10s - loss: 6.3729e-05 - mse: 6.3729e-05 - 10s/epoch - 4ms/step
# Epoch 13/100
# 2201/2201 - 10s - loss: 6.2631e-05 - mse: 6.2631e-05 - 10s/epoch - 4ms/step
# Epoch 14/100
# 2201/2201 - 10s - loss: 6.2325e-05 - mse: 6.2325e-05 - 10s/epoch - 4ms/step
# Epoch 15/100
# 2201/2201 - 10s - loss: 6.1187e-05 - mse: 6.1187e-05 - 10s/epoch - 4ms/step
# Epoch 16/100
# 2201/2201 - 10s - loss: 6.1344e-05 - mse: 6.1344e-05 - 10s/epoch - 4ms/step
# Epoch 17/100
# 2201/2201 - 10s - loss: 5.9928e-05 - mse: 5.9928e-05 - 10s/epoch - 4ms/step
# Epoch 18/100
# 2201/2201 - 10s - loss: 5.9792e-05 - mse: 5.9792e-05 - 10s/epoch - 4ms/step
# Epoch 19/100
# 2201/2201 - 10s - loss: 5.9486e-05 - mse: 5.9486e-05 - 10s/epoch - 4ms/step
# Epoch 20/100
# 2201/2201 - 10s - loss: 5.9060e-05 - mse: 5.9060e-05 - 10s/epoch - 4ms/step
# Epoch 21/100
# 2201/2201 - 10s - loss: 5.8433e-05 - mse: 5.8433e-05 - 10s/epoch - 4ms/step
# Epoch 22/100
# 2201/2201 - 10s - loss: 5.7911e-05 - mse: 5.7911e-05 - 10s/epoch - 4ms/step
# Epoch 23/100
# 2201/2201 - 10s - loss: 5.8264e-05 - mse: 5.8264e-05 - 10s/epoch - 4ms/step
# Epoch 24/100
# 2201/2201 - 9s - loss: 5.7361e-05 - mse: 5.7361e-05 - 9s/epoch - 4ms/step
# Epoch 25/100
# 2201/2201 - 10s - loss: 5.7324e-05 - mse: 5.7324e-05 - 10s/epoch - 4ms/step
# Epoch 26/100
# 2201/2201 - 10s - loss: 5.7350e-05 - mse: 5.7350e-05 - 10s/epoch - 4ms/step
# Epoch 27/100
# 2201/2201 - 10s - loss: 5.6876e-05 - mse: 5.6876e-05 - 10s/epoch - 4ms/step
# Epoch 28/100
# 2201/2201 - 10s - loss: 5.6865e-05 - mse: 5.6865e-05 - 10s/epoch - 4ms/step
# Epoch 29/100
# 2201/2201 - 10s - loss: 5.6972e-05 - mse: 5.6972e-05 - 10s/epoch - 4ms/step
# Epoch 30/100
# 2201/2201 - 10s - loss: 5.7199e-05 - mse: 5.7199e-05 - 10s/epoch - 4ms/step
# Epoch 31/100
# 2201/2201 - 10s - loss: 5.6413e-05 - mse: 5.6413e-05 - 10s/epoch - 4ms/step
# Epoch 32/100
# 2201/2201 - 10s - loss: 5.6651e-05 - mse: 5.6651e-05 - 10s/epoch - 5ms/step
# Epoch 33/100
# 2201/2201 - 10s - loss: 5.6677e-05 - mse: 5.6677e-05 - 10s/epoch - 5ms/step
# Epoch 34/100
# 2201/2201 - 10s - loss: 5.6468e-05 - mse: 5.6468e-05 - 10s/epoch - 4ms/step
# 2201/2201 [==============================] - 5s 2ms/step
# 1084/1084 [==============================] - 3s 2ms/step
# -------------
# Pompstation Wageningseberg\Flow
# NaN
# Pompstation La Cabine\Head
# Epoch 1/100
# 2201/2201 - 11s - loss: 0.0189 - mse: 0.0189 - 11s/epoch - 5ms/step
# Epoch 2/100
# 2201/2201 - 10s - loss: 3.0134e-04 - mse: 3.0134e-04 - 10s/epoch - 4ms/step
# Epoch 3/100
# 2201/2201 - 10s - loss: 2.5728e-04 - mse: 2.5728e-04 - 10s/epoch - 5ms/step
# Epoch 4/100
# 2201/2201 - 10s - loss: 2.1893e-04 - mse: 2.1893e-04 - 10s/epoch - 5ms/step
# Epoch 5/100
# 2201/2201 - 10s - loss: 2.0159e-04 - mse: 2.0159e-04 - 10s/epoch - 5ms/step
# Epoch 6/100
# 2201/2201 - 10s - loss: 1.9307e-04 - mse: 1.9307e-04 - 10s/epoch - 5ms/step
# Epoch 7/100
# 2201/2201 - 10s - loss: 1.8798e-04 - mse: 1.8798e-04 - 10s/epoch - 5ms/step
# Epoch 8/100
# 2201/2201 - 10s - loss: 1.8641e-04 - mse: 1.8641e-04 - 10s/epoch - 5ms/step
# Epoch 9/100
# 2201/2201 - 10s - loss: 1.8603e-04 - mse: 1.8603e-04 - 10s/epoch - 5ms/step
# Epoch 10/100
# 2201/2201 - 10s - loss: 1.8518e-04 - mse: 1.8518e-04 - 10s/epoch - 5ms/step
# Epoch 11/100
# 2201/2201 - 10s - loss: 1.8415e-04 - mse: 1.8415e-04 - 10s/epoch - 4ms/step
# Epoch 12/100
# 2201/2201 - 10s - loss: 1.8333e-04 - mse: 1.8333e-04 - 10s/epoch - 4ms/step
# Epoch 13/100
# 2201/2201 - 10s - loss: 1.8460e-04 - mse: 1.8460e-04 - 10s/epoch - 4ms/step
# Epoch 14/100
# 2201/2201 - 10s - loss: 1.8471e-04 - mse: 1.8471e-04 - 10s/epoch - 4ms/step
# Epoch 15/100
# 2201/2201 - 10s - loss: 1.8396e-04 - mse: 1.8396e-04 - 10s/epoch - 4ms/step
# 2201/2201 [==============================] - 5s 2ms/step
# 1084/1084 [==============================] - 2s 2ms/step
# -------------

# %%
for i in results:
    print(i)
# Out:
# ('Ede\\Pompstation Edese bos\\Straat 03\\Flow', (24.760483278067362, 27.808596784094977))
# ('Oosterbeek-hoog\\Fletcher BV|Supplied', (0.1876138000380782, 0.19236711692151226))
# ('Renkum-Heelsum\\Parenco BV|Supplied', (0.38981021970616037, 0.3649765842151672))
# ('Renkum-Heelsum\\Zorggroep|Supplied', (0.1773401115267138, 0.18208379102614908))
# ('Pompstation Oosterbeek\\Straat 01\\Head', (0.32630830354702617, 0.7097312161050567))
# ('Pompstation Oosterbeek\\Straat 02\\Head', (0.36691698156184865, 0.2528286507241947))
# ('Reservoir Doorwerth\\Straat 01\\Flow', (7.4518741696859845, 5.313094872535263))
# ('Reservoir Doorwerth\\Straat 02\\Head', (0.12096356941639297, 0.22840064054007977))
# ('Reservoir Doorwerth\\Straat 03\\Flow', (14.213931393132043, 12.333341113422058))
# ('Pompstation Wageningseberg\\Head', (0.36173248284399206, 0.49926372312230355))
# ('Pompstation La Cabine\\Head', (0.6579024739678265, 0.5871266009311575))

# %%
lstm_results = [[i[0], i[1][0], i[1][1]] for i in results]
lstm_results.append(['Renkum-Heelsum\Renkum|Supplied', np.nan, np.nan])
lstm_results.append(['Pompstation Wageningseberg\Flow', np.nan, np.nan])
lstm_results = pd.DataFrame(lstm_results)


lstm_results.columns = ["Location", "Train RMSE", "Test RMSE"]
lstm_results.set_index("Location", inplace=True)
lstm_results.sort_index(inplace=True)

print(lstm_results.round(3).to_latex())
# Out:
# \begin{tabular}{lrr}
# \toprule
#  & Train RMSE & Test RMSE \\
# Location &  &  \\
# \midrule
# Ede\Pompstation Edese bos\Straat 03\Flow & 24.760000 & 27.809000 \\
# Oosterbeek-hoog\Fletcher BV|Supplied & 0.188000 & 0.192000 \\
# Pompstation La Cabine\Head & 0.658000 & 0.587000 \\
# Pompstation Oosterbeek\Straat 01\Head & 0.326000 & 0.710000 \\
# Pompstation Oosterbeek\Straat 02\Head & 0.367000 & 0.253000 \\
# Pompstation Wageningseberg\Flow & NaN & NaN \\
# Pompstation Wageningseberg\Head & 0.362000 & 0.499000 \\
# Renkum-Heelsum\Parenco BV|Supplied & 0.390000 & 0.365000 \\
# Renkum-Heelsum\Renkum|Supplied & NaN & NaN \\
# Renkum-Heelsum\Zorggroep|Supplied & 0.177000 & 0.182000 \\
# Reservoir Doorwerth\Straat 01\Flow & 7.452000 & 5.313000 \\
# Reservoir Doorwerth\Straat 02\Head & 0.121000 & 0.228000 \\
# Reservoir Doorwerth\Straat 03\Flow & 14.214000 & 12.333000 \\
# \bottomrule
# \end{tabular}
